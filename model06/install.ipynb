# %%
# !sudo apt update && sudo apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install gym[all]
# Out:
# Hit:1 http://packages.cloud.google.com/apt cloud-sdk-buster InRelease
# Hit:2 http://security.debian.org/debian-security buster/updates InRelease
# Get:3 http://packages.cloud.google.com/apt google-cloud-packages-archive-keyring-buster InRelease [5553 B]
# Hit:4 http://deb.debian.org/debian buster InRelease
# Hit:5 http://packages.cloud.google.com/apt gcsfuse-buster InRelease
# Hit:6 http://deb.debian.org/debian buster-updates InRelease
# Hit:7 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Hit:8 http://packages.cloud.google.com/apt google-compute-engine-buster-stable InRelease
# Hit:9 http://deb.debian.org/debian buster-backports InRelease
# Get:10 https://nvidia.github.io/libnvidia-container/stable/debian10/amd64  InRelease [1484 B]
# Get:12 https://download.docker.com/linux/debian buster InRelease [54.0 kB]
# Hit:13 https://nvidia.github.io/nvidia-container-runtime/stable/debian10/amd64  InRelease
# ...
